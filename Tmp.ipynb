# %%
#Automated reloading of custom modules
# %load_ext autoreload
# %autoreload 2

#Standard modules
import os
import time
import random

import numpy as np
import scipy

import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
from datetime import datetime

#Custom modules
import helpers as hlp
import models as mdl
import tmp
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
m = mdl.LeNet5(1, 100, 10)

class Dummy():
    def __init__(self, m):
        self.m = m
    
    def check(self):
        print(m.training)

# %%
pt, pt_global, ft = tmp.run(4, "MNIST", "LeNet5", reduced=0.1, rounds=50, fed_avg="model", export_dir="./saves")
# Out:
# Device: cuda
# ** Using MNIST **
# Load train data...
# Load validation data...
# Dataset sizes:
# 	- Train: (6000, 1, 28, 28) (18.864 MB)
# 	- Validation (1000, 1, 28, 28) (3.144 MB)
# Round 50 done. (2.1s)

# %%
pt, ft = tmp.run(4, "MNIST", "LeNet5", reduced=0.1, rounds=50, export_dir="./saves")
# Out:
# Device: cuda
# ** Using MNIST **
# Load train data...
# Load validation data...
# Dataset sizes:
# 	- Train: (6000, 1, 28, 28) (18.864 MB)
# 	- Validation (1000, 1, 28, 28) (3.144 MB)
# Round 50 done. (2.7s)

# %%
pt, ft = tmp.run(4, "MNIST", "LeNet5", reduced=0.1, lambda_kd=0, lambda_disc=0, rounds=50, export_dir="./saves")
# Out:
# Device: cuda
# ** Using MNIST **
# Load train data...
# Load validation data...
# Dataset sizes:
# 	- Train: (6000, 1, 28, 28) (18.864 MB)
# 	- Validation (1000, 1, 28, 28) (3.144 MB)
# Round 50 done. (1.5s)
